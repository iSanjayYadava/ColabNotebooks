# %% [markdown]
# <a href="https://colab.research.google.com/github/iSanjayYadava/ColabNotebooks/blob/master/jyoti.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
# %reload_ext autoreload
# %autoreload 2

# %%
from google.colab import drive
drive.mount('/content/gdrive')
# Out:
# Go to this URL in a browser: https://accounts.google.com/o/oauth2/auth?client_id=947318989803-6bn6qk8qdgf4n4g3pfee6491hc0brc4i.apps.googleusercontent.com&redirect_uri=urn%3Aietf%3Awg%3Aoauth%3A2.0%3Aoob&scope=email%20https%3A%2F%2Fwww.googleapis.com%2Fauth%2Fdocs.test%20https%3A%2F%2Fwww.googleapis.com%2Fauth%2Fdrive%20https%3A%2F%2Fwww.googleapis.com%2Fauth%2Fdrive.photos.readonly%20https%3A%2F%2Fwww.googleapis.com%2Fauth%2Fpeopleapi.readonly&response_type=code
#
# Enter your authorization code:
# ··········
# Mounted at /content/gdrive

# %%
#export
import sys
sys.path.append('/content/gdrive/My Drive/ColabNotebooks/')

# %%
from pathlib import Path
DATA_PATH = Path('/content/gdrive/My Drive/ColabNotebooks/data')
PATH = DATA_PATH/'toclassify'

# %%
def find_classes(folder:Path):
    "Return class subdirectories in imagenet style train `folder`"
    classes = [d for d in folder.iterdir()
               if d.is_dir() and not d.name.startswith('.')]
    assert(len(classes)>0)
    return sorted(classes, key=lambda d: d.name)

# %%
find_classes(PATH)
# Out:
# [PosixPath('/content/gdrive/My Drive/ColabNotebooks/data/toclassify/cwx'),
#  PosixPath('/content/gdrive/My Drive/ColabNotebooks/data/toclassify/ra'),
#  PosixPath('/content/gdrive/My Drive/ColabNotebooks/data/toclassify/rsh'),
#  PosixPath('/content/gdrive/My Drive/ColabNotebooks/data/toclassify/src'),
#  PosixPath('/content/gdrive/My Drive/ColabNotebooks/data/toclassify/tpm')]

# %%
classes = [cls.name for cls in find_classes(PATH)]

# %%
classes
# Out:
# ['cwx', 'ra', 'rsh', 'src', 'tpm']

# %%
def get_image_files(c:Path, check_ext:bool=False):
    "Return list of files in `c` that are images. `check_ext` will filter to `image_extensions`."
    return [o for o in list(c.iterdir())
            if not (o.name.startswith('.') or o.is_dir()
            or (check_ext and o.suffix not in image_extensions))]

# %%
def from_folder(folder:Path, classes=None, 
                    valid_pct:float=0.):
        "Dataset of `classes` labeled images in `folder`. Optional `valid_pct` split validation set."
        if classes is None: classes = [cls.name for cls in find_classes(PATH)]
            
        fns,labels = [],[]
        for cl in classes:
            print(cl)
            f = get_image_files(folder/cl, check_ext=False)
            fns+=f; 
            lbl = [cl]*len(f)
            labels+=lbl
            
        return fns,labels

# %%
fns,lbl = from_folder(PATH)
# Out:
# cwx
# ra
# rsh
# src
# tpm

# %%
fns
# Out:
# [PosixPath('/content/gdrive/My Drive/ColabNotebooks/data/toclassify/cwx/66414'),
#  PosixPath('/content/gdrive/My Drive/ColabNotebooks/data/toclassify/cwx/66415'),
#  PosixPath('/content/gdrive/My Drive/ColabNotebooks/data/toclassify/cwx/66419'),
#  PosixPath('/content/gdrive/My Drive/ColabNotebooks/data/toclassify/cwx/66411'),
#  PosixPath('/content/gdrive/My Drive/ColabNotebooks/data/toclassify/cwx/66416'),
#  PosixPath('/content/gdrive/My Drive/ColabNotebooks/data/toclassify/cwx/66420'),
#  PosixPath('/content/gdrive/My Drive/ColabNotebooks/data/toclassify/cwx/66417'),
#  PosixPath('/content/gdrive/My Drive/ColabNotebooks/data/toclassify/cwx/66418'),
#  PosixPath('/content/gdrive/My Drive/ColabNotebooks/data/toclassify/cwx/66413'),
#  PosixPath('/content/gdrive/My Drive/ColabNotebooks/data/toclassify/cwx/66412'),
#  PosixPath('/content/gdrive/My Drive/ColabNotebooks/data/toclassify/cwx/66423'),
#  PosixPath('/content/gdrive/My Drive/ColabNotebooks/data/toclassify/cwx/66426'),
# ...

# %%
lbl
# Out:
# ['cwx',
#  'cwx',
#  'cwx',
#  'cwx',
#  'cwx',
#  'cwx',
#  'cwx',
#  'cwx',
#  'cwx',
#  'cwx',
#  'cwx',
#  'cwx',
#  'cwx',
#  'cwx',
#  'cwx',
#  'cwx',
#  'cwx',
#  'cwx',
#  'cwx',
#  'cwx',
#  'cwx',
#  'cwx',
#  'cwx',
#  'cwx',
#  'cwx',
#  'cwx',
#  'cwx',
#  'cwx',
#  'cwx',
#  'cwx',
#  'cwx',
#  'cwx',
#  'cwx',
#  'cwx',
#  'cwx',
#  'cwx',
#  'cwx',
#  'cwx',
#  'cwx',
#  'cwx',
#  'cwx',
#  'cwx',
#  'cwx',
#  'cwx',
#  'cwx',
#  'cwx',
#  'cwx',
#  'cwx',
#  'cwx',
#  'cwx',
#  'ra',
#  'ra',
#  'ra',
#  'ra',
#  'ra',
#  'ra',
#  'ra',
#  'ra',
#  'ra',
#  'ra',
#  'ra',
#  'ra',
#  'ra',
#  'ra',
#  'ra',
#  'ra',
#  'ra',
#  'ra',
#  'ra',
#  'ra',
#  'ra',
#  'ra',
#  'ra',
#  'ra',
#  'ra',
#  'ra',
#  'ra',
#  'ra',
#  'ra',
#  'ra',
#  'ra',
#  'ra',
#  'ra',
#  'ra',
#  'ra',
#  'ra',
#  'ra',
#  'ra',
#  'ra',
#  'ra',
#  'ra',
#  'ra',
#  'ra',
#  'ra',
#  'ra',
#  'ra',
#  'ra',
#  'ra',
#  'ra',
#  'ra',
#  'rsh',
#  'rsh',
#  'rsh',
#  'rsh',
#  'rsh',
# ...
